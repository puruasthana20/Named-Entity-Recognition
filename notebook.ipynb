# %%
# !pip install spacy pandas
# Out:
# Requirement already satisfied: spacy in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (3.8.5)
# Requirement already satisfied: pandas in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (2.2.2)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from spacy) (0.15.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.1.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from spacy) (2.10.6)
# Requirement already satisfied: jinja2 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from spacy) (74.1.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from spacy) (24.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from spacy) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: language-data>=1.2 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.27.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.12.2)
# Requirement already satisfied: six>=1.5 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2024.8.30)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.7)
# Requirement already satisfied: shellingham>=1.3.0 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from jinja2->spacy) (2.1.5)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in c:\users\purua\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv("ner_large_unprocessed_dataset.csv")

# Preview
print(df.head())
print(df.columns)
# Out:
#                                             Sentence  \
# 0  Kindle was launched by Microsoft at the World ...
# 1          Sarah visited Mumbai during the Olympics.
# 2  The Last Supper is displayed at a museum in Pa...
# 3                  Olivia donated €1 billion to WHO.
# 4  The Sydney Opera House is a famous monument in...
#
#                                             Entities
# 0  [(23, 32, 'ORG'), (0, 6, 'PRODUCT'), (40, 49, ...
# 1  [(0, 5, 'PER'), (14, 20, 'LOC'), (32, 40, 'EVE...
# 2          [(44, 49, 'LOC'), (0, 15, 'WORK_OF_ART')]
# 3  [(0, 6, 'PER'), (29, 32, 'ORG'), (15, 25, 'MON...
# 4  [(47, 52, 'LOC'), (4, 10, 'LOC'), (4, 22, 'FAC...
# Index(['Sentence', 'Entities'], dtype='object')

# %%
import ast

# Safely convert string of list of tuples to actual list
df['Entities'] = df['Entities'].apply(ast.literal_eval)

# Check example
print(df.iloc[0])
# Out:
# Sentence    Kindle was launched by Microsoft at the World ...
# Entities    [(23, 32, ORG), (0, 6, PRODUCT), (40, 49, EVENT)]
# Name: 0, dtype: object

# %%
import spacy
from spacy.tokens import DocBin

nlp = spacy.blank("en")  # blank English pipeline
doc_bin = DocBin()

for i, row in df.iterrows():
    text = row['Sentence']
    entities = row['Entities']

    doc = nlp.make_doc(text)
    ents = []
    
    # Sort entities by their start position to avoid overlap
    entities = sorted(entities, key=lambda x: x[0])

    # Ensure no overlaps in entities
    for start, end, label in entities:
        # Check for overlapping entities with existing ones
        is_overlapping = any(start < existing_end and end > existing_start for existing_start, existing_end, _ in ents)
        if is_overlapping:
            print(f"⚠️ Skipping overlapping span: {(start, end, label)} in '{text}'")
        else:
            span = doc.char_span(start, end, label=label, alignment_mode="contract")
            if span is None:
                print(f"⚠️ Skipping invalid span: {(start, end, label)} in '{text}'")
            else:
                ents.append((start, end, label))  # Store as tuple for overlap check

    # Assign valid entity spans to doc
    doc.ents = [doc.char_span(start, end, label=label) for start, end, label in ents]
    doc_bin.add(doc)

# Save to file
doc_bin.to_disk("data.spacy")
# Out:
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Paris.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Cairo.'
# ⚠️ Skipping overlapping span: (24, 26, 'ORG') in 'Michael donated $100 to UNICEF.'
# ⚠️ Skipping overlapping span: (23, 25, 'ORG') in 'iPhone was launched by UNICEF at the Super Bowl.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Berlin.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new iPhone on January 1st.'
# ⚠️ Skipping overlapping span: (29, 31, 'ORG') in 'Olivia donated $5 million to UNICEF.'
# ⚠️ Skipping overlapping span: (28, 30, 'ORG') in 'PlayStation was launched by UNICEF at the Comic-Con.'
# ⚠️ Skipping overlapping span: (23, 25, 'ORG') in 'iPhone was launched by UNICEF at the Super Bowl.'
# ⚠️ Skipping overlapping span: (23, 25, 'ORG') in 'Olivia donated €200 to UNICEF.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Mumbai.'
# ⚠️ Skipping overlapping span: (36, 42, 'NATIONALITY') in 'Michael wrote about Starry Night in French.'
# ⚠️ Skipping overlapping span: (13, 19, 'NATIONALITY') in 'Robert is an French citizen working in Berlin.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new PlayStation on 2023.'
# ⚠️ Skipping overlapping span: (13, 19, 'NATIONALITY') in 'Sophia is an French citizen working in Tokyo.'
# ⚠️ Skipping overlapping span: (28, 30, 'ORG') in 'Sarah donated $5 million to UNICEF.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new MacBook Pro on August 15.'
# ⚠️ Skipping overlapping span: (13, 19, 'NATIONALITY') in 'Sophia is an French citizen working in Toronto.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new Surface Pro on August 15.'
# ⚠️ Skipping overlapping span: (31, 37, 'NATIONALITY') in 'Alice wrote about Mona Lisa in French.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF follows the Patent Act strictly.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF follows the Patent Act strictly.'
# ⚠️ Skipping overlapping span: (36, 42, 'NATIONALITY') in 'Emma wrote about The Last Supper in French.'
# ⚠️ Skipping overlapping span: (12, 18, 'NATIONALITY') in 'Sarah is an French citizen working in Paris.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Paris.'
# ⚠️ Skipping overlapping span: (14, 20, 'NATIONALITY') in 'Michael is an French citizen working in Rome.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Sydney.'
# ⚠️ Skipping overlapping span: (30, 36, 'NATIONALITY') in 'Liam wrote about Mona Lisa in French.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new Galaxy S22 on January 1st.'
# ⚠️ Skipping overlapping span: (31, 37, 'NATIONALITY') in 'Sarah wrote about Mona Lisa in French.'
# ⚠️ Skipping overlapping span: (28, 30, 'ORG') in 'Sarah donated $5 million to UNICEF.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Cairo.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF raised €200 in April.'
# ⚠️ Skipping overlapping span: (11, 17, 'NATIONALITY') in 'Liam is an French citizen working in Berlin.'
# ⚠️ Skipping overlapping span: (32, 38, 'NATIONALITY') in 'Robert wrote about Mona Lisa in French.'
# ⚠️ Skipping overlapping span: (28, 30, 'ORG') in 'MacBook Pro was launched by UNICEF at the Comic-Con.'
# ⚠️ Skipping overlapping span: (12, 18, 'NATIONALITY') in 'David is an French citizen working in Paris.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF follows the GDPR strictly.'
# ⚠️ Skipping overlapping span: (35, 41, 'NATIONALITY') in 'Sophia wrote about Starry Night in French.'
# ⚠️ Skipping overlapping span: (11, 17, 'NATIONALITY') in 'Emma is an French citizen working in New York.'
# ⚠️ Skipping overlapping span: (27, 29, 'ORG') in 'John donated €1 billion to UNICEF.'
# ⚠️ Skipping overlapping span: (31, 37, 'NATIONALITY') in 'Sophia wrote about Guernica in French.'
# ⚠️ Skipping overlapping span: (13, 19, 'NATIONALITY') in 'Robert is an French citizen working in Tokyo.'
# ⚠️ Skipping overlapping span: (21, 23, 'ORG') in 'Emma donated $100 to UNICEF.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Berlin.'
# ⚠️ Skipping overlapping span: (28, 30, 'ORG') in 'Surface Pro was launched by UNICEF at the Coachella.'
# ⚠️ Skipping overlapping span: (13, 19, 'NATIONALITY') in 'Olivia is an French citizen working in Mumbai.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Rome.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new Pixel 8 on April.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Rome.'
# ⚠️ Skipping overlapping span: (27, 29, 'ORG') in 'John donated €1 billion to UNICEF.'
# ⚠️ Skipping overlapping span: (13, 19, 'NATIONALITY') in 'Sophia is an French citizen working in Tokyo.'
# ⚠️ Skipping overlapping span: (30, 36, 'NATIONALITY') in 'Sarah wrote about Guernica in French.'
# ⚠️ Skipping overlapping span: (29, 31, 'ORG') in 'Olivia donated $5 million to UNICEF.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Cairo.'
# ⚠️ Skipping overlapping span: (13, 19, 'NATIONALITY') in 'Olivia is an French citizen working in London.'
# ⚠️ Skipping overlapping span: (29, 31, 'ORG') in 'Robert donated €1 billion to UNICEF.'
# ⚠️ Skipping overlapping span: (37, 43, 'NATIONALITY') in 'Alice wrote about The Last Supper in French.'
# ⚠️ Skipping overlapping span: (12, 18, 'NATIONALITY') in 'Sarah is an French citizen working in Rome.'
# ⚠️ Skipping overlapping span: (11, 17, 'NATIONALITY') in 'Liam is an French citizen working in Berlin.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new iPhone on August 15.'
# ⚠️ Skipping overlapping span: (27, 29, 'ORG') in 'Galaxy S22 was launched by UNICEF at the Super Bowl.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Rome.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Tokyo.'
# ⚠️ Skipping overlapping span: (36, 42, 'NATIONALITY') in 'John wrote about The Last Supper in French.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Mumbai.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF follows the HIPAA strictly.'
# ⚠️ Skipping overlapping span: (13, 19, 'NATIONALITY') in 'Sophia is an French citizen working in Cairo.'
# ⚠️ Skipping overlapping span: (28, 30, 'ORG') in 'Surface Pro was launched by UNICEF at the Comic-Con.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new iPhone on April.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Toronto.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in New York.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF raised €200 in April.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new Surface Pro on June 5.'
# ⚠️ Skipping overlapping span: (28, 30, 'ORG') in 'PlayStation was launched by UNICEF at the Super Bowl.'
# ⚠️ Skipping overlapping span: (38, 44, 'NATIONALITY') in 'Robert wrote about The Last Supper in French.'
# ⚠️ Skipping overlapping span: (34, 40, 'NATIONALITY') in 'Alice wrote about Starry Night in French.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new Galaxy S22 on January 1st.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in London.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF raised $100 in Monday.'
# ⚠️ Skipping overlapping span: (34, 40, 'NATIONALITY') in 'David wrote about Starry Night in French.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new MacBook Pro on Monday.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in New York.'
# ⚠️ Skipping overlapping span: (23, 25, 'ORG') in 'Sophia donated €200 to UNICEF.'
# ⚠️ Skipping overlapping span: (39, 45, 'NATIONALITY') in 'Michael wrote about The Last Supper in French.'
# ⚠️ Skipping overlapping span: (13, 19, 'NATIONALITY') in 'Robert is an French citizen working in Mumbai.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF follows the HIPAA strictly.'
# ⚠️ Skipping overlapping span: (29, 35, 'NATIONALITY') in 'Emma wrote about Guernica in French.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Paris.'
# ⚠️ Skipping overlapping span: (37, 43, 'NATIONALITY') in 'Sarah wrote about The Last Supper in French.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF follows the GDPR strictly.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Cairo.'
# ⚠️ Skipping overlapping span: (28, 30, 'ORG') in 'MacBook Pro was launched by UNICEF at the Olympics.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new Galaxy S22 on January 1st.'
# ⚠️ Skipping overlapping span: (28, 30, 'ORG') in 'PlayStation was launched by UNICEF at the Coachella.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF follows the GDPR strictly.'
# ⚠️ Skipping overlapping span: (30, 36, 'NATIONALITY') in 'Alice wrote about Guernica in French.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new iPhone on April.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Paris.'
# ⚠️ Skipping overlapping span: (30, 36, 'NATIONALITY') in 'Sarah wrote about Guernica in French.'
# ⚠️ Skipping overlapping span: (12, 18, 'NATIONALITY') in 'Sarah is an French citizen working in Berlin.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF raised €1 billion in August 15.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new PlayStation on Monday.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Sydney.'
# ⚠️ Skipping overlapping span: (13, 19, 'NATIONALITY') in 'Robert is an French citizen working in Tokyo.'
# ⚠️ Skipping overlapping span: (31, 37, 'NATIONALITY') in 'Alice wrote about Mona Lisa in French.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF raised €1 billion in August 15.'
# ⚠️ Skipping overlapping span: (30, 36, 'NATIONALITY') in 'Emma wrote about Mona Lisa in French.'
# ⚠️ Skipping overlapping span: (12, 18, 'NATIONALITY') in 'David is an French citizen working in London.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Toronto.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Berlin.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Cairo.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Cairo.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new iPhone on December 2024.'
# ⚠️ Skipping overlapping span: (21, 23, 'ORG') in 'John donated $100 to UNICEF.'
# ⚠️ Skipping overlapping span: (11, 17, 'NATIONALITY') in 'Liam is an French citizen working in Sydney.'
# ⚠️ Skipping overlapping span: (14, 20, 'NATIONALITY') in 'Michael is an French citizen working in New York.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF follows the HIPAA strictly.'
# ⚠️ Skipping overlapping span: (34, 40, 'NATIONALITY') in 'Alice wrote about Starry Night in French.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF follows the GDPR strictly.'
# ⚠️ Skipping overlapping span: (29, 35, 'NATIONALITY') in 'Liam wrote about Guernica in French.'
# ⚠️ Skipping overlapping span: (24, 26, 'ORG') in 'Pixel 8 was launched by UNICEF at the Coachella.'
# ⚠️ Skipping overlapping span: (12, 18, 'NATIONALITY') in 'David is an French citizen working in Sydney.'
# ⚠️ Skipping overlapping span: (11, 17, 'NATIONALITY') in 'Emma is an French citizen working in Sydney.'
# ⚠️ Skipping overlapping span: (28, 30, 'ORG') in 'PlayStation was launched by UNICEF at the World Cup.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Mumbai.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new Pixel 8 on April.'
# ⚠️ Skipping overlapping span: (30, 36, 'NATIONALITY') in 'John wrote about Mona Lisa in French.'
# ⚠️ Skipping overlapping span: (34, 40, 'NATIONALITY') in 'Alice wrote about Starry Night in French.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF raised €200 in January 1st.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF follows the HIPAA strictly.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Sydney.'

# %%
import spacy
from spacy.tokens import DocBin
from sklearn.model_selection import train_test_split

# Train-test split
train, dev = train_test_split(df, test_size=0.2)

# Initialize spaCy blank model
nlp = spacy.blank("en")

def create_spacy_file(df, filename):
    doc_bin = DocBin()
    for i, row in df.iterrows():
        text = row["Sentence"]
        entities = row["Entities"]
        
        doc = nlp.make_doc(text)
        ents = []
        
        # Sort entities by start position to avoid overlaps
        entities = sorted(entities, key=lambda x: x[0])

        # Create entity spans and check for overlaps
        for start, end, label in entities:
            # Check if the entity span overlaps with an existing one
            if any(start < existing_end and end > existing_start for existing_start, existing_end, _ in ents):
                print(f"⚠️ Skipping overlapping span: {(start, end, label)} in '{text}'")
            else:
                span = doc.char_span(start, end, label=label, alignment_mode="contract")
                if span:
                    ents.append((start, end, label))  # Store as tuple for overlap check

        # Set valid entity spans
        doc.ents = [doc.char_span(start, end, label=label) for start, end, label in ents]
        doc_bin.add(doc)

    doc_bin.to_disk(filename)

# Create spaCy files for train and dev sets
create_spacy_file(train, "train.spacy")
create_spacy_file(dev, "dev.spacy")
# Out:
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF raised €200 in April.'
# ⚠️ Skipping overlapping span: (30, 36, 'NATIONALITY') in 'Alice wrote about Guernica in French.'
# ⚠️ Skipping overlapping span: (27, 29, 'ORG') in 'John donated €1 billion to UNICEF.'
# ⚠️ Skipping overlapping span: (12, 18, 'NATIONALITY') in 'David is an French citizen working in Paris.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new iPhone on December 2024.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new iPhone on January 1st.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new iPhone on April.'
# ⚠️ Skipping overlapping span: (29, 31, 'ORG') in 'Robert donated €1 billion to UNICEF.'
# ⚠️ Skipping overlapping span: (13, 19, 'NATIONALITY') in 'Sophia is an French citizen working in Tokyo.'
# ⚠️ Skipping overlapping span: (29, 35, 'NATIONALITY') in 'Liam wrote about Guernica in French.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new Surface Pro on August 15.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Toronto.'
# ⚠️ Skipping overlapping span: (31, 37, 'NATIONALITY') in 'Sophia wrote about Guernica in French.'
# ⚠️ Skipping overlapping span: (13, 19, 'NATIONALITY') in 'Robert is an French citizen working in Mumbai.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Berlin.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Paris.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF follows the HIPAA strictly.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Paris.'
# ⚠️ Skipping overlapping span: (23, 25, 'ORG') in 'Sophia donated €200 to UNICEF.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new iPhone on August 15.'
# ⚠️ Skipping overlapping span: (24, 26, 'ORG') in 'Pixel 8 was launched by UNICEF at the Coachella.'
# ⚠️ Skipping overlapping span: (30, 36, 'NATIONALITY') in 'Liam wrote about Mona Lisa in French.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new Galaxy S22 on January 1st.'
# ⚠️ Skipping overlapping span: (13, 19, 'NATIONALITY') in 'Sophia is an French citizen working in Toronto.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new PlayStation on 2023.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Paris.'
# ⚠️ Skipping overlapping span: (23, 25, 'ORG') in 'Olivia donated €200 to UNICEF.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new Pixel 8 on April.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new Surface Pro on June 5.'
# ⚠️ Skipping overlapping span: (13, 19, 'NATIONALITY') in 'Robert is an French citizen working in Berlin.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in London.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF follows the HIPAA strictly.'
# ⚠️ Skipping overlapping span: (11, 17, 'NATIONALITY') in 'Liam is an French citizen working in Sydney.'
# ⚠️ Skipping overlapping span: (13, 19, 'NATIONALITY') in 'Robert is an French citizen working in Tokyo.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF follows the GDPR strictly.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new Pixel 8 on April.'
# ⚠️ Skipping overlapping span: (14, 20, 'NATIONALITY') in 'Michael is an French citizen working in New York.'
# ⚠️ Skipping overlapping span: (31, 37, 'NATIONALITY') in 'Alice wrote about Mona Lisa in French.'
# ⚠️ Skipping overlapping span: (39, 45, 'NATIONALITY') in 'Michael wrote about The Last Supper in French.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF follows the Patent Act strictly.'
# ⚠️ Skipping overlapping span: (12, 18, 'NATIONALITY') in 'David is an French citizen working in Sydney.'
# ⚠️ Skipping overlapping span: (34, 40, 'NATIONALITY') in 'Alice wrote about Starry Night in French.'
# ⚠️ Skipping overlapping span: (21, 23, 'ORG') in 'Emma donated $100 to UNICEF.'
# ⚠️ Skipping overlapping span: (27, 29, 'ORG') in 'Galaxy S22 was launched by UNICEF at the Super Bowl.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF raised €1 billion in August 15.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Paris.'
# ⚠️ Skipping overlapping span: (13, 19, 'NATIONALITY') in 'Olivia is an French citizen working in London.'
# ⚠️ Skipping overlapping span: (13, 19, 'NATIONALITY') in 'Olivia is an French citizen working in Mumbai.'
# ⚠️ Skipping overlapping span: (11, 17, 'NATIONALITY') in 'Liam is an French citizen working in Berlin.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Cairo.'
# ⚠️ Skipping overlapping span: (28, 30, 'ORG') in 'Surface Pro was launched by UNICEF at the Coachella.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Sydney.'
# ⚠️ Skipping overlapping span: (36, 42, 'NATIONALITY') in 'John wrote about The Last Supper in French.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new Galaxy S22 on January 1st.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Berlin.'
# ⚠️ Skipping overlapping span: (12, 18, 'NATIONALITY') in 'Sarah is an French citizen working in Paris.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF follows the HIPAA strictly.'
# ⚠️ Skipping overlapping span: (38, 44, 'NATIONALITY') in 'Robert wrote about The Last Supper in French.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Tokyo.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF follows the Patent Act strictly.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new Galaxy S22 on January 1st.'
# ⚠️ Skipping overlapping span: (11, 17, 'NATIONALITY') in 'Emma is an French citizen working in New York.'
# ⚠️ Skipping overlapping span: (31, 37, 'NATIONALITY') in 'Sarah wrote about Mona Lisa in French.'
# ⚠️ Skipping overlapping span: (11, 17, 'NATIONALITY') in 'Liam is an French citizen working in Berlin.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Mumbai.'
# ⚠️ Skipping overlapping span: (28, 30, 'ORG') in 'PlayStation was launched by UNICEF at the Super Bowl.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF follows the GDPR strictly.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new MacBook Pro on August 15.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF raised €200 in April.'
# ⚠️ Skipping overlapping span: (35, 41, 'NATIONALITY') in 'Sophia wrote about Starry Night in French.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in New York.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new iPhone on April.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new PlayStation on Monday.'
# ⚠️ Skipping overlapping span: (28, 30, 'ORG') in 'MacBook Pro was launched by UNICEF at the Olympics.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Mumbai.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF raised €1 billion in August 15.'
# ⚠️ Skipping overlapping span: (28, 30, 'ORG') in 'PlayStation was launched by UNICEF at the Coachella.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Rome.'
# ⚠️ Skipping overlapping span: (29, 31, 'ORG') in 'Olivia donated $5 million to UNICEF.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Rome.'
# ⚠️ Skipping overlapping span: (28, 30, 'ORG') in 'PlayStation was launched by UNICEF at the Comic-Con.'
# ⚠️ Skipping overlapping span: (28, 30, 'ORG') in 'Sarah donated $5 million to UNICEF.'
# ⚠️ Skipping overlapping span: (36, 42, 'NATIONALITY') in 'Emma wrote about The Last Supper in French.'
# ⚠️ Skipping overlapping span: (23, 25, 'ORG') in 'iPhone was launched by UNICEF at the Super Bowl.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF follows the GDPR strictly.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Toronto.'
# ⚠️ Skipping overlapping span: (14, 20, 'NATIONALITY') in 'Michael is an French citizen working in Rome.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF follows the GDPR strictly.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Cairo.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Sydney.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Mumbai.'
# ⚠️ Skipping overlapping span: (11, 17, 'NATIONALITY') in 'Emma is an French citizen working in Sydney.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF raised €200 in January 1st.'
# ⚠️ Skipping overlapping span: (34, 40, 'NATIONALITY') in 'Alice wrote about Starry Night in French.'
# ⚠️ Skipping overlapping span: (23, 25, 'ORG') in 'iPhone was launched by UNICEF at the Super Bowl.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF raised $100 in Monday.'
# ⚠️ Skipping overlapping span: (34, 40, 'NATIONALITY') in 'Alice wrote about Starry Night in French.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Sydney.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Cairo.'
# ⚠️ Skipping overlapping span: (30, 36, 'NATIONALITY') in 'Sarah wrote about Guernica in French.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Cairo.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Cairo.'
# ⚠️ Skipping overlapping span: (37, 43, 'NATIONALITY') in 'Sarah wrote about The Last Supper in French.'
# ⚠️ Skipping overlapping span: (28, 30, 'ORG') in 'Sarah donated $5 million to UNICEF.'
# ⚠️ Skipping overlapping span: (29, 35, 'NATIONALITY') in 'Emma wrote about Guernica in French.'
# ⚠️ Skipping overlapping span: (13, 19, 'NATIONALITY') in 'Sophia is an French citizen working in Cairo.'
# ⚠️ Skipping overlapping span: (32, 38, 'NATIONALITY') in 'Robert wrote about Mona Lisa in French.'
# ⚠️ Skipping overlapping span: (12, 18, 'NATIONALITY') in 'David is an French citizen working in London.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Rome.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF announced a new MacBook Pro on Monday.'
# ⚠️ Skipping overlapping span: (13, 19, 'NATIONALITY') in 'Sophia is an French citizen working in Tokyo.'
# ⚠️ Skipping overlapping span: (28, 30, 'ORG') in 'Surface Pro was launched by UNICEF at the Comic-Con.'
# ⚠️ Skipping overlapping span: (30, 36, 'NATIONALITY') in 'Sarah wrote about Guernica in French.'
# ⚠️ Skipping overlapping span: (30, 36, 'NATIONALITY') in 'Emma wrote about Mona Lisa in French.'
# ⚠️ Skipping overlapping span: (12, 18, 'NATIONALITY') in 'Sarah is an French citizen working in Berlin.'
# ⚠️ Skipping overlapping span: (27, 29, 'ORG') in 'John donated €1 billion to UNICEF.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Berlin.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in New York.'
# ⚠️ Skipping overlapping span: (21, 23, 'ORG') in 'John donated $100 to UNICEF.'
# ⚠️ Skipping overlapping span: (28, 30, 'ORG') in 'PlayStation was launched by UNICEF at the World Cup.'
# ⚠️ Skipping overlapping span: (0, 2, 'ORG') in 'UNICEF follows the HIPAA strictly.'
# ⚠️ Skipping overlapping span: (34, 40, 'NATIONALITY') in 'David wrote about Starry Night in French.'
# ⚠️ Skipping overlapping span: (31, 37, 'NATIONALITY') in 'Alice wrote about Mona Lisa in French.'
# ⚠️ Skipping overlapping span: (29, 31, 'ORG') in 'Olivia donated $5 million to UNICEF.'
# ⚠️ Skipping overlapping span: (30, 36, 'NATIONALITY') in 'John wrote about Mona Lisa in French.'
# ⚠️ Skipping overlapping span: (36, 42, 'NATIONALITY') in 'Michael wrote about Starry Night in French.'
# ⚠️ Skipping overlapping span: (37, 43, 'NATIONALITY') in 'Alice wrote about The Last Supper in French.'
# ⚠️ Skipping overlapping span: (28, 30, 'ORG') in 'MacBook Pro was launched by UNICEF at the Comic-Con.'
# ⚠️ Skipping overlapping span: (24, 26, 'ORG') in 'Michael donated $100 to UNICEF.'
# ⚠️ Skipping overlapping span: (13, 19, 'NATIONALITY') in 'Robert is an French citizen working in Tokyo.'
# ⚠️ Skipping overlapping span: (12, 18, 'NATIONALITY') in 'Sarah is an French citizen working in Rome.'
# ⚠️ Skipping overlapping span: (4, 22, 'FACILITY') in 'The Sydney Opera House is a famous monument in Cairo.'

# %%
import spacy

# Load the trained model
nlp = spacy.load("output/model-best")

# Test on a new sentence
doc = nlp("Apple is looking at buying U.K. startup for $1 billion")

for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Apple ORG
# U.K. NATIONALITY
# $1 billion MONEY

# %%
import spacy
nlp = spacy.load("en_pipeline")
